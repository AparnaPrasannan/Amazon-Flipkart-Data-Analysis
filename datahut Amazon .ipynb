# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('F:/Amazon.in _ microwave oven.csv')

# %%
data1.head()
# Out:
#                                                 Text         rating  \
# 0           LG 28 L Convection Microwave Oven (MC...  2,573 ratings
# 1           LG 32 L Convection Microwave Oven (MC...  2,256 ratings
# 2           IFB 20 L Convection Microwave Oven (2...  4,883 ratings
# 3           IFB 20 L Grill Microwave Oven (20PG4S...    499 ratings
# 4           IFB 30 L Convection Microwave Oven (3...  1,276 ratings
#
#   sales_price      mrp brand                                diamension  \
# 0      11,699  ₹16,999    LG        23.5D x 42.5W x 41H Centimeters
# 1      16,999  ₹23,999    LG          31.5D x 53W x 52H Centimeters
# 2      10,690  ₹14,490   IFB                                       NaN
# 3       7,950  ₹10,590   IFB      26.2D x 45.2W x 36.5H Centimeters
# 4      12,990  ₹17,990   IFB        30D x 53.9W x 43.8H Centimeters
#
#    product_rating                                seller  \
# 0             4.4  DAWNTECH ELECTRONICS PRIVATE LIMITED
# ...

# %%
data=data1.drop(['first_date_avilable','tech_details','home_kitch_rank','sub_cat_rank'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Text               143 non-null    object
#  1   rating             90 non-null     object
#  2   sales_price        79 non-null     object
#  3   mrp                79 non-null     object
#  4   brand              127 non-null    object
#  5   diamension         32 non-null     object
#  6   product_rating     90 non-null     float64
#  7   seller             66 non-null     object
#  8   capacity           134 non-null    object
#  9   installation_type  100 non-null    object
#  10  additional_info    143 non-null    object
#  11  weight             70 non-null     object
#  12  generic_name       44 non-null     object
#  13  asin               139 non-null    object
#  14  model              142 non-null    object
# dtypes: float64(1), object(14)
# ...

# %%
for i in data.columns:
  print(data[i].value_counts())
  print('---------------------------------------------')
# Out:
#          LG 28 L Convection Microwave Oven (MC2846BV, Black)                                                                                                 1
#          Samsung 28 L Convection Microwave Oven (MC28A5025QB/TL, Black with Pattern, slimfry)                                                                1
#          SRI NEW KARNATAKA ELECTRONICS MICROWAVE OVEN MODEL - 9                                                                                              1
#          SRI NEW KARNATAKA ELECTRONICS MICROWAVE OVEN MODEL - 4                                                                                              1
#          SRI NEW KARNATAKA ELECTRONICS MICROWAVE OVEN MODEL - 3                                                                                              1
#                                                                                                                                                             ..
# ...

# %%
data.isna().sum()
# Out:
# Text                   0
# rating                53
# sales_price           64
# mrp                   64
# brand                 16
# diamension           111
# product_rating        53
# seller                77
# capacity               9
# installation_type     43
# additional_info        0
# weight                73
# generic_name          99
# asin                   4
# model                  1
# dtype: int64

# %%
print(f"We have {data.duplicated().sum()} duplicate values")
# Out:
# We have 0 duplicate values

# %%
data.describe()   ## statistical summary
# Out:
#        product_rating
# count       90.000000
# mean         4.027778
# std          0.709966
# min          1.000000
# 25%          3.850000
# 50%          4.200000
# 75%          4.400000
# max          5.000000

# %%
data.describe(include='O')
# Out:
#                                                      Text    rating  \
# count                                                 143        90
# unique                                                143        61
# top              LG 28 L Convection Microwave Oven (MC...  1 rating
# freq                                                    1        11
#
#        sales_price        mrp brand                            diamension  \
# count           79         79   127                                    32
# unique          74         66    33                                    30
# top         12,990  ₹6,299.00    LG      52D x 53W x 32.2H Centimeters
# freq             3         11    18                                     2
#
#                                       seller                       capacity  \
# count                                     66                            134
# unique                                    18                             66
# ...

# %%
data = data.fillna(data.mode().iloc[0])
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Text               143 non-null    object
#  1   rating             143 non-null    object
#  2   sales_price        143 non-null    object
#  3   mrp                143 non-null    object
#  4   brand              143 non-null    object
#  5   diamension         143 non-null    object
#  6   product_rating     143 non-null    float64
#  7   seller             143 non-null    object
#  8   capacity           143 non-null    object
#  9   installation_type  143 non-null    object
#  10  additional_info    143 non-null    object
#  11  weight             143 non-null    object
#  12  generic_name       143 non-null    object
#  13  asin               143 non-null    object
#  14  model              143 non-null    object
# dtypes: float64(1), object(14)
# ...

# %%
data.isna().sum()
# Out:
# Text                 0
# rating               0
# sales_price          0
# mrp                  0
# brand                0
# diamension           0
# product_rating       0
# seller               0
# capacity             0
# installation_type    0
# additional_info      0
# weight               0
# generic_name         0
# asin                 0
# model                0
# dtype: int64

# %%
data.to_csv('C:/Users/HP/Desktop/ap_python/Amazon.csv')

# %%
data1['installation_type']
# Out:
# 0             \n                ‎MC2846BV
# 1           \n                ‎MC3286BRUM
# 2           \n                ‎Countertop
# 3           \n                ‎Countertop
# 4                \n                ‎30SC4
#                       ...
# 138           \n                ‎Standard
# 139                                    NaN
# 140                                    NaN
# 141         \n                ‎1800 Watts
# 142    \n                ‎Stainless Steel
# Name: installation_type, Length: 143, dtype: object

# %%
data1['additional_info']
# Out:
# 0          Additional Information                    ...
# 1          Additional Information                    ...
# 2          Additional Information                    ...
# 3          Additional Information                    ...
# 4          Additional Information                    ...
#                              ...
# 138        Additional Information                    ...
# 139        Additional Information                    ...
# 140        Additional Information                    ...
# 141        Additional Information                    ...
# 142        Additional Information                    ...
# Name: additional_info, Length: 143, dtype: object

# %%
data1['brand'].unique()
# Out:
# array(['LG', 'IFB', 'Morphy Richards', 'Whirlpool', 'Samsung',
#        'Panasonic', 'Voltas Beko', 'Haier', 'Faber', 'Godrej', 'Bajaj',
#        'Generic', nan, 'Siemens', 'Bosch', 'KAFF Appliances', 'Carysil',
#        'Kaff', 'Kenstar', 'Westinghouse', 'MODA GERMANY', 'GLAB',
#        'Hindware', 'Glen', 'Kraft Italy', 'Hafele', 'Wonderchef',
#        'Avanti', 'ELECTROPRIME', 'Crofton', 'AKIVIN', 'Nuwave',
#        'ConXport', 'Sharper Image'], dtype=object)
