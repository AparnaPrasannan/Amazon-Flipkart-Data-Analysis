# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('F:\_flipkart_new.csv')

# %%
data
# Out:
#      Unnamed: 0                                        product_url  \
# 0             0  https://www.flipkart.com/samsung-21-l-convecti...
# 1             1  https://www.flipkart.com/samsung-32-l-convecti...
# 2             2  https://www.flipkart.com/ifb-23-l-convection-m...
# 3             3  https://www.flipkart.com/bajaj-17-l-solo-micro...
# 4             4  https://www.flipkart.com/samsung-28-l-convecti...
# ..          ...                                                ...
# 170         170  https://www.flipkart.com/lg-32-l-convection-mi...
# 171         171  https://www.flipkart.com/samsung-23-l-solo-mic...
# 172         172  https://www.flipkart.com/kenstar-20-l-solo-mic...
# 173         173  https://www.flipkart.com/haier-25-l-convection...
# 174         174  https://www.flipkart.com/samsung-32-l-convecti...
#
#                                       product_title  rating  \
# 0            SAMSUNG 21 L Convection Microwave Oven     4.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          175 non-null    int64
#  1   product_url         175 non-null    object
#  2   product_title       175 non-null    object
#  3   rating              175 non-null    float64
#  4   number_of_reviews   175 non-null    object
#  5   description         175 non-null    object
#  6   seller_name         175 non-null    object
#  7   mrp                 175 non-null    object
#  8   sales_price         175 non-null    object
#  9   product_dimensions  175 non-null    object
#  10  general             175 non-null    object
#  11  type                175 non-null    object
#  12  model               175 non-null    object
#  13  Capacity            174 non-null    object
#  14  brand               175 non-null    object
# ...

# %%
for i in data.columns:
  print(data[i].value_counts())
  print('---------------------------------------------')
# Out:
# 0      1
# 120    1
# 112    1
# 113    1
# 114    1
#       ..
# 60     1
# 61     1
# 62     1
# 63     1
# 174    1
# Name: Unnamed: 0, Length: 175, dtype: int64
# ---------------------------------------------
# https://www.flipkart.com/samsung-21-l-convection-microwave-oven/p/itm8891a3360f67f?pid=MRCGDAVXQXUHAAHY&lid=LSTMRCGDAVXQXUHAAHYCEEAX9&marketplace=FLIPKART&q=microwave+oven&store=j9e%2Fm38%2Fo49&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=organic&iid=en_GdOK82n089sdM7R9%2FDKfg%2Fyx1hY7I8CZ%2BMTTl0JbWMwQCCOfidPADC13zXJvKCY2ifKcrOPB%2FkV9f419rWStzg%3D%3D&ppt=None&ppn=None&ssid=s95f8w6rf40000001686243210752&qH=473b4abe03a500c3       1
# ...

# %%
data.isin(['â']).sum(axis=0)
# Out:
# Unnamed: 0            0
# product_url           0
# product_title         0
# rating                0
# number_of_reviews     0
# description           0
# seller_name           0
# mrp                   0
# sales_price           0
# product_dimensions    0
# general               0
# type                  0
# model                 0
# Capacity              0
# brand                 0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Unnamed: 0            0
# product_url           0
# product_title         0
# rating                0
# number_of_reviews     0
# description           0
# seller_name           0
# mrp                   0
# sales_price           0
# product_dimensions    0
# general               0
# type                  0
# model                 0
# Capacity              1
# brand                 0
# dtype: int64

# %%
print(f"We have {data.duplicated().sum()} duplicate values")
# Out:
# We have 0 duplicate values

# %%
data.describe()   ## statistical summary
# Out:
#        Unnamed: 0      rating
# count  175.000000  175.000000
# mean    87.000000    4.330857
# std     50.662281    0.222232
# min      0.000000    2.800000
# 25%     43.500000    4.300000
# 50%     87.000000    4.400000
# 75%    130.500000    4.400000
# max    174.000000    5.000000

# %%
data.describe(include='O')
# Out:
#                                               product_url  \
# count                                                 175
# unique                                                175
# top     https://www.flipkart.com/samsung-21-l-convecti...
# freq                                                    1
#
#                             product_title            number_of_reviews  \
# count                                 175                          175
# unique                                 76                          112
# top     LG 28 L Convection Microwave Oven  2,706 Ratings & 317 Reviews
# freq                                   16                           38
#
#         description        seller_name     mrp sales_price  \
# count           175                175     175         175
# unique           81                 41     118         126
# top     User Manual  OmniTechRetail4.9  20,000      13,490
# freq             17                 50      14           8
#
# ...

# %%
data['rating'].value_counts()
# Out:
# 4.4    80
# 4.3    39
# 4.2    18
# 4.5    10
# 4.6     6
# 4.0     6
# 4.1     6
# 4.7     3
# 3.8     2
# 5.0     2
# 3.9     1
# 2.8     1
# 3.0     1
# Name: rating, dtype: int64

# %%
data['number_of_reviews'].value_counts()
# Out:
# 2,706 Ratings & 317 Reviews      38
# 8,243 Ratings & 1,055 Reviews     6
# 8,375 Ratings & 753 Reviews       6
# 4 Ratings & 0 Reviews             3
# 6,783 Ratings & 755 Reviews       2
#                                  ..
# 1,282 Ratings & 111 Reviews       1
# 208 Ratings & 27 Reviews          1
# 49 Ratings & 1 Reviews            1
# 3,424 Ratings & 493 Reviews       1
# 26 Ratings & 0 Reviews            1
# Name: number_of_reviews, Length: 112, dtype: int64

# %%
data = data.fillna(data.mode().iloc[0])
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          175 non-null    int64
#  1   product_url         175 non-null    object
#  2   product_title       175 non-null    object
#  3   rating              175 non-null    float64
#  4   number_of_reviews   175 non-null    object
#  5   description         175 non-null    object
#  6   seller_name         175 non-null    object
#  7   mrp                 175 non-null    object
#  8   sales_price         175 non-null    object
#  9   product_dimensions  175 non-null    object
#  10  general             175 non-null    object
#  11  type                175 non-null    object
#  12  model               175 non-null    object
#  13  Capacity            175 non-null    object
#  14  brand               175 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0            0
# product_url           0
# product_title         0
# rating                0
# number_of_reviews     0
# description           0
# seller_name           0
# mrp                   0
# sales_price           0
# product_dimensions    0
# general               0
# type                  0
# model                 0
# Capacity              0
# brand                 0
# dtype: int64

# %%
data
# Out:
#      Unnamed: 0                                        product_url  \
# 0             0  https://www.flipkart.com/samsung-21-l-convecti...
# 1             1  https://www.flipkart.com/samsung-32-l-convecti...
# 2             2  https://www.flipkart.com/ifb-23-l-convection-m...
# 3             3  https://www.flipkart.com/bajaj-17-l-solo-micro...
# 4             4  https://www.flipkart.com/samsung-28-l-convecti...
# ..          ...                                                ...
# 170         170  https://www.flipkart.com/lg-32-l-convection-mi...
# 171         171  https://www.flipkart.com/samsung-23-l-solo-mic...
# 172         172  https://www.flipkart.com/kenstar-20-l-solo-mic...
# 173         173  https://www.flipkart.com/haier-25-l-convection...
# 174         174  https://www.flipkart.com/samsung-32-l-convecti...
#
#                                       product_title  rating  \
# 0            SAMSUNG 21 L Convection Microwave Oven     4.4
# ...

# %%
data.to_csv('C:/Users/HP/Desktop/ap_python/_flipkart_new.csv')

# %%
data['brand']
# Out:
# 0      SAMSUNG
# 1      SAMSUNG
# 2          IFB
# 3        BAJAJ
# 4      SAMSUNG
#         ...
# 170         LG
# 171    SAMSUNG
# 172    Kenstar
# 173      Haier
# 174    SAMSUNG
# Name: brand, Length: 175, dtype: object

# %%
data['Capacity'].unique()
# Out:
# array(['21 L', '32 L', '23 L', '17L', '28 L', '20 L', '20L', '32L', '30L',
#        '28L', '21L', '24 L', '27 L', '25 L', '23L', '25L', '30 L', nan,
#        'IFB', '17 L', '70 L'], dtype=object)
